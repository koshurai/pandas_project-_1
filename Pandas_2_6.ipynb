# %% [markdown]
# #Pandas Series and DataFrames
# - Difference
# - Usage

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5])

s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.shape
# Out:
# (5,)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %%
s.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
s.head(2)
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-737b0f036c3e> in <cell line: 0>()
# ----> 1 s.columns
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
s.dtypes
# Out:
# dtype('int64')

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#s['column_name']

# %%
s+2
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
s=s*2

# %%
s
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
temp = pd.Series([25,28,19,20,29])
rain_chances = pd.Series([30,45,80,20,67])

df = pd.DataFrame()
df['Temp'] = temp
df['Rain_Chances'] = rain_chances

df
# Out:
#    Temp  Rain_Chances
# 0    25            30
# 1    28            45
# 2    19            80
# 3    20            20
# 4    29            67

# %%
df
# Out:
#    Temp  Rain_Chances
# 0    25            30
# 1    28            45
# 2    19            80
# 3    20            20
# 4    29            67

# %%
type(df['Temp'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#    Temp  Rain_Chances
# 0    25            30
# 1    28            45
# 2    19            80
# 3    20            20
# 4    29            67

# %%
#fetch data from row number 2

df[df.index==2]
# Out:
#    Temp  Rain_Chances
# 2    19            80

# %%
#fetch data from row number 2 and 3 both
df[(df.index==2) | (df.index==3)]
# Out:
#    Temp  Rain_Chances
# 2    19            80
# 3    20            20

# %%
df
# Out:
#    Temp  Rain_Chances
# 0    25            30
# 1    28            45
# 2    19            80
# 3    20            20
# 4    29            67

# %%
df.loc[2:4]
# Out:
#    Temp  Rain_Chances
# 2    19            80
# 3    20            20
# 4    29            67

# %%
path='/content/ecommerce_product_performance.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 0     199.671415       0.177024        4.411071               62.0
# 1     136.173570       0.041467        3.033534              201.0
# 2     214.768854       0.276197        2.866881              479.0
# 3     302.302986       0.094254        4.473473              252.0
# 4     126.584663       0.411845        3.553082              671.0
#
#    Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# 0                 1.0              9.0     0.185116          5.0
# 1                 1.0              3.0     0.384639         10.0
# 2                 1.0             19.0     0.056410          4.0
# 3                 1.0             11.0          NaN          7.0
# 4                 1.0             14.0     0.672163          6.0

# %%
#fetch rows 3 through 10

df.loc[3:10]['Product_Rating']
# Out:
# 3     4.473473
# 4     3.553082
# 5     1.874022
# 6          NaN
# 7     3.366010
# 8     5.000000
# 9     5.000000
# 10    2.798990
# Name: Product_Rating, dtype: float64

# %%
df.loc[3:10][['Product_Rating','Number_of_Reviews']]
# Out:
#     Product_Rating  Number_of_Reviews
# 3         4.473473              252.0
# 4         3.553082              671.0
# 5         1.874022              303.0
# 6              NaN              350.0
# 7         3.366010              330.0
# 8         5.000000              179.0
# 9         5.000000              350.0
# 10        2.798990                NaN

# %%
df.head(2)
# Out:
#    Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 0     199.671415       0.177024        4.411071               62.0
# 1     136.173570       0.041467        3.033534              201.0
#
#    Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# 0                 1.0              9.0     0.185116          5.0
# 1                 1.0              3.0     0.384639         10.0

# %%
df.loc[[3,4],['Product_Rating']]
# Out:
#    Product_Rating
# 3        4.473473
# 4        3.553082

# %%
df.head()
# Out:
#    Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 0     199.671415       0.177024        4.411071               62.0
# 1     136.173570       0.041467        3.033534              201.0
# 2     214.768854       0.276197        2.866881              479.0
# 3     302.302986       0.094254        4.473473              252.0
# 4     126.584663       0.411845        3.553082              671.0
#
#    Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# 0                 1.0              9.0     0.185116          5.0
# 1                 1.0              3.0     0.384639         10.0
# 2                 1.0             19.0     0.056410          4.0
# 3                 1.0             11.0          NaN          7.0
# 4                 1.0             14.0     0.672163          6.0

# %%
#Number_of_Reviews>200

df[df['Number_of_Reviews']>200]
# Out:
#       Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 1        136.173570       0.041467        3.033534              201.0
# 2        214.768854       0.276197        2.866881              479.0
# 3        302.302986       0.094254        4.473473              252.0
# 4        126.584663       0.411845        3.553082              671.0
# 5        126.586304       0.515701        1.874022              303.0
# ...             ...            ...             ...                ...
# 1992            NaN       0.256828        3.495332              343.0
# 1995     257.015024       0.098708        3.805205              398.0
# 1996            NaN       0.679901        3.340395              788.0
# 1997      61.812535       0.081616        2.736741              297.0
# 1998     133.693304       0.346151        3.246759              467.0
#
#       Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# ...

# %%
df[(df['Number_of_Reviews']>200) & (df['Product_Rating']>4)]
# Out:
#       Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 3        302.302986       0.094254        4.473473              252.0
# 9        204.256004       0.301962        5.000000              350.0
# 11       103.427025       0.277367        4.833190              589.0
# 18              NaN       0.174789        4.943566              454.0
# 25       161.092259       0.085522        4.191829              314.0
# ...             ...            ...             ...                ...
# 1965     158.958068       0.235899        5.000000              278.0
# 1968     130.509172       0.152270        4.102972              234.0
# 1979     190.705229       0.332031        4.937858             1675.0
# 1986     222.509579       0.049595        5.000000              771.0
# 1991     225.429133       0.177269        4.479373              260.0
#
#       Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# ...

# %%
df.head()
# Out:
#    Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 0     199.671415       0.177024        4.411071               62.0
# 1     136.173570       0.041467        3.033534              201.0
# 2     214.768854       0.276197        2.866881              479.0
# 3     302.302986       0.094254        4.473473              252.0
# 4     126.584663       0.411845        3.553082              671.0
#
#    Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# 0                 1.0              9.0     0.185116          5.0
# 1                 1.0              3.0     0.384639         10.0
# 2                 1.0             19.0     0.056410          4.0
# 3                 1.0             11.0          NaN          7.0
# 4                 1.0             14.0     0.672163          6.0

# %%
df['rating'] = round(df['Product_Rating'])

# %%
df.head()
# Out:
#    Product_Price  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 0     199.671415       0.177024        4.411071               62.0
# 1     136.173570       0.041467        3.033534              201.0
# 2     214.768854       0.276197        2.866881              479.0
# 3     302.302986       0.094254        4.473473              252.0
# 4     126.584663       0.411845        3.553082              671.0
#
#    Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID  rating
# 0                 1.0              9.0     0.185116          5.0     4.0
# 1                 1.0              3.0     0.384639         10.0     3.0
# 2                 1.0             19.0     0.056410          4.0     3.0
# 3                 1.0             11.0          NaN          7.0     4.0
# 4                 1.0             14.0     0.672163          6.0     4.0

# %%
#reorder columns
df.columns
# Out:
# Index(['Product_Price', 'Discount_Rate', 'Product_Rating', 'Number_of_Reviews',
#        'Stock_Availability', 'Days_to_Deliver', 'Return_Rate', 'Category_ID',
#        'rating'],
#       dtype='object')

# %%
df=df[['Product_Price','rating' ,'Discount_Rate', 'Product_Rating', 'Number_of_Reviews',
       'Stock_Availability', 'Days_to_Deliver', 'Return_Rate', 'Category_ID',
       ]]

df.head()
# Out:
#    Product_Price  rating  Discount_Rate  Product_Rating  Number_of_Reviews  \
# 0     199.671415     4.0       0.177024        4.411071               62.0
# 1     136.173570     3.0       0.041467        3.033534              201.0
# 2     214.768854     3.0       0.276197        2.866881              479.0
# 3     302.302986     4.0       0.094254        4.473473              252.0
# 4     126.584663     4.0       0.411845        3.553082              671.0
#
#    Stock_Availability  Days_to_Deliver  Return_Rate  Category_ID
# 0                 1.0              9.0     0.185116          5.0
# 1                 1.0              3.0     0.384639         10.0
# 2                 1.0             19.0     0.056410          4.0
# 3                 1.0             11.0          NaN          7.0
# 4                 1.0             14.0     0.672163          6.0

# %%
for row in df.iterrows():
  print(row[1][0],'----',row[1][1])
# Out:
# 199.6714153011233 ---- 4.0
# 136.17356988288154 ---- 3.0
# 214.76885381006923 ---- 3.0
# 302.30298564080255 ---- 4.0
# 126.5846625276664 ---- 4.0
# 126.58630430508194 ---- 2.0
# 307.92128155073914 ---- nan
# 226.74347291529088 ---- 3.0
# 103.0525614065048 ---- 5.0
# 204.25600435859647 ---- 5.0
# 103.65823071875376 ---- 3.0
# 103.42702464297432 ---- 5.0
# 174.1962271566034 ---- 3.0
# 5.0 ---- 2.0
# 5.0 ---- 3.0
# 93.77124707590272 ---- 4.0
# 48.71688796655762 ---- 3.0
# 181.4247332595274 ---- 3.0
# nan ---- 5.0
# 8.769629866470865 ---- nan
# 296.56487689215544 ---- 3.0
# 127.42236995134644 ---- 5.0
# 156.75282046879238 ---- 4.0
# nan ---- 1.0
# 95.56172754748174 ---- 4.0
# 161.09225897098662 ---- 4.0
# 34.90064225776972 ---- 4.0
# 187.5698018345672 ---- 5.0
# 89.9361310081195 ---- 3.0
# 120.83062502067231 ---- 4.0
# 89.82933877706031 ---- 2.0
# 335.2278184508938 ---- 4.0
# 148.6502775262066 ---- 5.0
# 44.22890710440997 ---- 3.0
# 232.2544912103189 ---- 3.0
# ...
